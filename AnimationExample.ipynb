# %%
# %matplotlib notebook
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.animation as animation

# %%
fig = plt.figure()

def f(x, y):
    return np.sin(x) + np.cos(y)

x = np.linspace(0, 2*np.pi, 120)
y = np.linspace(0, 2*np.pi, 100).reshape(-1, 1)
im = plt.imshow(f(x, y), animated=True, origin="lower",
               extent=(0, 2.0*np.pi, 0, 2.0*np.pi))

def updatefig(*args):
    global x, y
    x += np.pi/15.0
    y += np.pi/20.0
    im.set_array(f(x,y))
    return im,

ani = animation.FuncAnimation(fig, updatefig, interval=5, blit=True)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
fig = plt.figure()

# def f(x, y):
#     return np.sin(x) + np.cos(y)

# x = np.linspace(0, 2*np.pi, 120)
# y = np.linspace(0, 2*np.pi, 100).reshape(-1, 1)
randArr = np.random.rand(120, 100)
im = plt.imshow(randArr, animated=True)

def updatefig(*args):
    global x, y
    randArr = np.random.rand(120,100)
    im.set_array(randArr)
    return im,

ani = animation.FuncAnimation(fig, updatefig, interval=5, blit=True)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
a = np.linspace(0, 2*np.pi, 12)
b = np.linspace(0, 2*np.pi, 10)
print(a.shape)
print(b.shape)
print(a)
print(b)
np.reshape
b = np.linspace(0, 2*np.pi, 10).reshape(-1,1)
print(b.shape)
print(b)
c = a + b
print(c.shape)
print(c)
# Out:
# (12,)
# (10,)
# [0.         0.57119866 1.14239733 1.71359599 2.28479466 2.85599332
#  3.42719199 3.99839065 4.56958931 5.14078798 5.71198664 6.28318531]
# [0.         0.6981317  1.3962634  2.0943951  2.7925268  3.4906585
#  4.1887902  4.88692191 5.58505361 6.28318531]
# (10, 1)
# [[0.        ]
#  [0.6981317 ]
#  [1.3962634 ]
#  [2.0943951 ]
#  [2.7925268 ]
#  [3.4906585 ]
#  [4.1887902 ]
#  [4.88692191]
#  [5.58505361]
#  [6.28318531]]
# (10, 12)
# [[ 0.          0.57119866  1.14239733  1.71359599  2.28479466  2.85599332
#    3.42719199  3.99839065  4.56958931  5.14078798  5.71198664  6.28318531]
#  [ 0.6981317   1.26933037  1.84052903  2.41172769  2.98292636  3.55412502
#    4.12532369  4.69652235  5.26772102  5.83891968  6.41011834  6.98131701]
#  [ 1.3962634   1.96746207  2.53866073  3.10985939  3.68105806  4.25225672
#    4.82345539  5.39465405  5.96585272  6.53705138  7.10825004  7.67944871]
#  [ 2.0943951   2.66559377  3.23679243  3.8079911   4.37918976  4.95038842
# ...
